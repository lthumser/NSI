# %% [markdown]
# <div class=titre1 >Manipuler des BDD avec python</div>
# <img src="https://www.lebigdata.fr/wp-content/uploads/2018/01/bases-de-donnees-1024x734.jpg" width=400 />

# %% [markdown]
# <div class=attention >Avant de commencer : Kernel > Restart & Run All <br/><img src=danger.png width=24 style=display:inline-block; /> Penser à télécharger (File > Download as notebook .ipynb) régulièrement votre travail.
# </div>

# %% [markdown]
# <div class=titre2 >1. Bibliothèque sqlite3</div>
#
# Cette bibliothèque python permet de réaliser des requêtes SQlite sur une base de données.

# %%
import sqlite3

# %% [markdown]
# Le code suivant permet de se connecter à une base de données déjà existante dans votre dossier local.
#
# Remarque : Si la base de données n'est pas présente, ce code permet de la créer.

# %%
connexion = sqlite3.connect('base_de_donnees.db')

# %% [markdown]
# <div class=titre2 >2. Exécuter des requêtes sur une BDD</div>
# <p>Avant d'exécuter des requêtes sur la BDD, on crée une variable <span class=surligne >cur</span> avec le code ci-dessous :</p>

# %%
cur = connexion.cursor()

# %% [markdown]
# On peut ensuite exécuter une requête SQL avec le code ci-dessous :
#
#
# <code>cur.execute(SQL)</code>

# %% [markdown]
# <div class=attention ><img src=danger.png width=24  style=display:inline-block; />On ne peut exécuter qu'une seule requête SQL à la fois !</div>
#
# Donc une suite de requêtes s'écrira :
#
# <code>SQL = "..."</code>
#
# <code>cur.execute(SQL)</code>
#
# <code>SQL = "..."</code>
#
# <code>cur.execute(SQL)</code>

# %% [markdown]
# <div class=attention ><img src=danger.png width=24 style=display:inline-block; /> Le curseur s'autodétruit à chaque fois qu'on l'interroge. Tester en exécutant à nouveau le code précédent : plus de résultat ! Il faut donc réexécuter la requête à chaque fois avant de lancer un code utilisant le curseur.</div>
#
# Par exemple :
#
# <code>SQL = "select ..."</code>
#
# <code>cur.execute(SQL)</code>
#
# <code>print("premier affichage des résultats de la requête",list(cur))</code>
#
# <code>print("second affichage des résultats de la requête",list(cur))</code>
#
# Le seconde affichage de la requête ne donne rien ! 😒

# %% [markdown]
# <div class=titre2 >3. Création d'une BDD</div>
#
# <p>Créer la BDD <i style=background-color:orange >BDD_navigateurs.db</i> puis créer la table <i style=background-color:orange >navigateurs</i> avec le code SQL suivant :</p>
#
# <code>CREATE TABLE IF NOT EXISTS `navigateurs` (
#   `index` integer PRIMARY KEY AUTOINCREMENT,
#   `navigateur` tinytext NOT NULL,
#   `visites` int(11) NOT NULL default '0'
# );</code>
#
# <code>INSERT INTO `navigateurs` (`navigateur`, `visites`) VALUES
# ('Chrome', 361625),
# ('Internet Explorer', 19625),
# ('Firefox', 75435),
# ('Opera', 3047),
# ('Safari', 73499),
# ('inconnu', 40945),
# ('IE Edge', 5025);</code>

# %%
#taper votre code ici ...

# %% [markdown]
# Vérifier que votre BDD a bien été créée avec File > Open
#
# <p>Quel est le poids de votre BDD ?</p>
#
# <br/>
# <div class=reponse>Votre réponse : .......................</div>
#
# <br/>
# <div class=attention ><img src=danger.png width=24 style=display:inline-block; /> Répondre dans les pointillés, ne pas modifier le style !</div>

# %% [markdown]
# Réaliser une lecture ligne à ligne des enregistrements de la table navigateurs :

# %%
#taper votre requête SQL ici et décommenter les lignes ...

#cur.execute(SQL)
#for ligne in cur:
    #print(ligne)

# %% [markdown]
# De quel type est la variable ligne ?
#
# <br/>
# <div class=reponse>Votre réponse : .......................</div>

# %% [markdown]
# Remarque : le code suivant permet d'exporter votre BDD au format sql

# %%
nom_de_la_BDD = "BDD_navigateurs.sql"
with open(nom_de_la_BDD, 'w') as f:
    for line in connexion.iterdump():
        f.write('%s\n' % line)
connexion.close()

# %% [markdown]
# <p>Quel est le poids de votre BDD dans ce format ? Comparer avec le poids de la BDD sous le format db.</p>
# <div class=reponse>Vos réponses : .......................</div>

# %% [markdown]
# <div class=titre2 >4. Ouverture d'une BDD existante</div>

# %% [markdown]
# <p>Ce dossier jupyter contient la BDD <span class=surligne >exoplanetes.db</span>
# <br/>Ecrire le code qui permet de l'ouvrir :
# </p>

# %%
#taper votre code ici ...

# %% [markdown]
# La requête SQL suivante permet d'afficher la structure de la table <span class=surligne >exoplanetes</span> :
# <br>
# <code>pragma table_info(exoplanetes)</code>
#
# Réalisez ci-dessous cette requête :

# %%
#taper votre code ici ...

# %% [markdown]
# <p>Quel est l'indice de l'attribut name ?</p>
# <p>Quel est l'attribut ayant pour indice 76 ?</p>
# <br>
# <div class=reponse>Vos réponses : .......................</div>

# %% [markdown]
# A l'aide de l'attribut <span class=surligne >discovered</span>, écrire ci-dessous le code
# qui permet à l'aide d'une requête d'afficher la phrase "Kepler-186 f a été découverte en ..." où les pointillés sont complétés par la réponse.

# %%
#taper votre code ici ...

# %% [markdown]
# <p>De même, réaliser l'affichage du nom et du rayon (radius) de toutes les exoplanètes qui gravitent autour de l'étoile Kepler-186 :</p>

# %%
#taper votre code ici ...

# %% [markdown]
# <div class=titre2 >5. Travaux Pratiques</div>
# <div class=titre3 >a. Histogramme des masses</div>
# <p>Dans la BDD <i>exoplanetes.db</i>, sélectionner toutes les planètes dont la masse <u>et</u> dont le rayon sont connus <code>IS NOT NULL</code>.</p>
# <p>Ranger ces masses et ces rayons dans deux listes python appelées <span class=surligne >masses</span> et <span class=surligne >rayons</i>.</span>
# <p>Tracer l'histogramme des masses avec 80 barres.</p>
# <p><u>Aide :</u> <a href=http://phychiinfo.free.fr/informatique/langages/aide_memoire_pyplot.php target=_blank >cours sur la bibliothèque pyplot</a>

# %%
#taper votre code ici pour obtenir les listes masses et rayons...


masses = []
rayons = []


#Tracé de l'histogramme :    
# %matplotlib notebook
import matplotlib.pyplot as plt

fig, axes = plt.subplots() # on prépare une nouvelle figure 
axes.hist(masses, bins=800, facecolor='#44FF88', alpha=0.6, range = (0,4.5)) 
# range correspond à l'intervalle de valeurs utilisées
# alpha est la transparence des barres
axes.set(xlim=(0,0.4)) # on zoome sur cet intervalle de valeurs, mais le reste de la figure reste accessible par déplacement dans la figure 
axes.set_title('masses des exoplanètes') # le titre
axes.set(xlabel='masse ($x M_{Jupiter}$)', ylabel='fréquence') # titre des axes
print() # astuce pour éviter d'afficher la dernière ligne évaluée par python
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <p>Commenter l'histogramme sur la distribution des masses des exoplanètes</p>
# <div class=reponse>Votre réponse : .......................</div>
#
# <div class=titre3 >b. Histogramme des rayons</div>
# <p>Tracer maintenant d'une autre couleur l'histogramme des rayons (de 0 à 10 masses de Jupiter) avec 80 barres.</p>

# %%
#taper votre code ici...

# %% [markdown]
# <p>Rédiger un commentaire de cet histogramme en répondant notamment aux questions suivantes :</p>
# <ul>
#     <li>Sauf rares exceptions, quel est le rayon maximum des exoplanètes ?</li>
#     <li>Combien de groupes de planètes se distinguent ? Pour chacun de ces groupes, quel est le rayon le plus fréquent ?</li>
# </ul>
# <div class=reponse>Vos réponses : .......................</div>

# %% [markdown]
# <p>Réajuster le code du graphe pour tenir compte du rayon maximum des exoplanètes, passer à 80 barres pour avoir un histogramme plus régulier : </p>

# %%
#taper votre code ici...

# %% [markdown]
# <div class=titre3 >c. Nuage de points</div>
# <p>A l'aide de la fonction <b>scatter</b>, tracer le nuage de points des rayons en fonction des masses et commenter :</p>
# <p>De nombreux points étants proches, donner une transparence de 0.1 aux points pour bien observer la densité des nuages.</p>

# %%
#taper votre code ici ...

# %% [markdown]
# <div class=titre3 >d. Échelle logarithmique</div>
# <p>Les points étant tous très proches de l'axe des ordonnées, le graphe est peu clair, le passage en échelle logarithmique apportera beaucoup de clarté.</p>
# <p>Utiliser le code <code>axes.set(xscale='log')</code> pour l'axe des abscisses et de même pour l'axe des ordonnées.</p>

# %%
#taper votre code ici ...

# %% [markdown]
# <p>Le problème c'est que le graphe est soit zoomé trop en arrière, soit trop en avant (selon que vous avez déclaré les échelles logarithmiques <u>avant</u> ou <u>après</u> le tracé du nuage).</p>
# <p><u>Solution :</u> réaliser "à la main" des zoom avant ou arrière pour trouver les encadrements idéaux pour les valeurs sur les deux axes puis les intégrer dans votre code :</p>

# %%
#taper votre code ici ...

# %% [markdown]
# <div class=titre3 >e. Positionner la Terre et Jupiter</div>
# <p>Combien de nuage de points distingue-t-on ?</p>
# <p>Sauriez-vous l'interpréter ?</p>
# <div class=reponse>Vos réponses : .......................</div>
# <img src="https://i.pinimg.com/originals/24/23/e0/2423e0ca107d3e6c70fb94613a69d699.jpg" width=400 />
# <p>Ajouter sur le graphe un point (de couleur différente !) correspondant à Jupiter de manière à situer toutes ces planètes par rapport à notre planète géante.</p>
# <p>Faire de même pour la Terre.</p>
# <p><u>Rappel :</u> masse de Jupiter = 317,8 masses terrestres et rayon de Jupiter = 69911 km soit 10,96 rayons terrestre.
# </p>
# <p>Choisir judicieusement les couleurs !</p>
# <p>Ajouter l'affichage des légendes avec le code <code>axes.legend(handles=[terre,jupiter])</code> après avoir défini la variable jupiter comme suit : <code>jupiter = axes.scatter(1,1,color='...',label="Jupiter")</code> et la variable terre de manière similaire.</p>

# %%
#taper votre code ici ...

# %% [markdown]
# <p>Que constatez-vous ? :</p>
# <div class=reponse>Votre réponse : .......................</div>

# %% [markdown]
# <div class=titre3 >f. La densité des planètes</div>
# <img src="rayons_masses_planetes_etoiles.jpg" width=800 />
# Les astronomes distinguent deux grandes familles de planètes : les planètes dites « telluriques » et les planètes dites « gazeuses ». Dans le Système solaire, Mercure, Vénus, la Terre et Mars sont des planètes telluriques alors que Jupiter, Saturne, Uranus et Neptune sont des planètes gazeuses.
# <br/>
# La nébuleuse de gaz primitive à l'origine de la naissance des planètes du Système solaire était majoritairement composée d'hydrogène et d'hélium, tout comme l'est le reste de l'univers (l'hydrogène étant l'élément le plus abondant). Cependant, sous l'effet de divers phénomènes physiques, ces éléments ont migré vers l'extérieur du système, ne laissant à l'intérieur presque que des éléments plus lourds tels que le silicium, le carbone ou le fer.
#
# <br/>
# Ainsi, les planètes internes du Système solaire, les planètes telluriques, sont essentiellement formées de minéraux et de roches qui s'organisent en trois enveloppes concentriques : le noyau, le manteau et la croûte. Leur densité est comprise entre 4 et 5,5.
# <br/>
# Les planètes gazeuses, quant à elles, se sont formées à partir des gaz disponibles à distance du Soleil. Elles présentent un noyau silicaté très réduit et une densité proche de celle de l'eau, comprise entre environ 0,70 et 1,70. Températures et pressions augmentent au fur et à mesure qu'on s'enfonce vers leur noyau.
# <br/>
# Privées de la majeure partie de la matière disponible dans la nébuleuse primitive, les planètes telluriques sont de tailles modestes comparées à celles qu'affichent les planètes gazeuses, également surnommées planètes géantes : un peu plus de 6.000 km de rayon pour la Terre contre quelque 70.000 km pour Jupiter.
# <br/>
# Du fait de leurs tailles modestes, les planètes telluriques, contrairement aux planètes gazeuses, n'ont pas été capables de s'orner d'anneaux ni de retenir un grand nombre de satellites.
# <br/>
# Dernières différences notables entre planètes telluriques et planètes gazeuses : leur période de rotation. En effet, si la Terre, par exemple, met environ 24 heures pour faire un tour sur elle-même, Jupiter présente une période de rotation de seulement 10 heures !
# <br/>
# <u>sources :</u>
# <a href="http://exoplanetes.esep.pro/images/illustrations/diagrammes/m_r_pdf.pdf" >exoplanetes.esep</a> ,
# <a href="https://www.futura-sciences.com/sciences/questions-reponses/astronomie-planete-tellurique-planete-gazeuse-differences-6462/">futura-sciences.com</a>
# <p>Interpréter maintenant les deux nuages de points :</p>
# <div class=reponse>Votre réponse : .......................</div>
# <p>Pour vérifier cette interprétation, vous allez tracer sur le graphe la courbe correspondant à une densité égale à celle de la Terre.</p>
# <p>En supposant qu'une planète est une boule homogène, montrer que la masse d'une planète est proportionnelle au cube de son rayon :</p>
# <div class=reponse>Votre réponse : .......................</div>
# <p>Calculer ce coefficient de proportionnalité k pour la Terre (<img src=http://phychiinfo.free.fr/i/danger.png width=24 style=display:inline-block; /> en unités de Jupiter !)</p>

# %%
#taper votre calcul ici ...

# %% [markdown]
# <div class=reponse>Votre réponse : .......................</div>
# <p>Ecrire le code python qui calcule dix valeurs de rayons sur l'intervalle choisi au paragraphe précédent : Comme l'échelle est logarithmique, partir de la borne inférieur et multiplier la valeur par 2 à chaque itération. Au bout de 10 itérations, on arrive à peu près à la borne supérieure.</p>

# %%
#taper votre code ici ...

# %% [markdown]
# <p>Pour les dix rayons calculés, calculer les dix masses correspondantes pour une densité égale à celle de la Terre :</p>

# %%
#taper votre code ici ...

# %% [markdown]
# <p>Intégrer ces valeurs calculées de la massee et du rayon dans deux listes puis tracer en pointillés la courbe avec la fonction <b>plot</p> :</p>

# %%
#taper votre code ici ...

# %% [markdown]
# <p>Indiquer la position de Jupiter et de son nuage de points par rapport à votre courbe et interpréter à l'aide du document.</p>
# <div class=reponse>Votre réponse : .......................</div>

# %% [markdown]
# <div class=titre3 >g. Intégrer les étoiles dans le graphe</div>
# <img src="https://upload.wikimedia.org/wikipedia/commons/4/42/Solar_prominence_from_STEREO_spacecraft_September_29%2C_2008.jpg" width=400 />
# <p>Récupérer les masses et les rayons des étoiles (star_mass en masse solaire et star_radius en rayon solaire) dans votre graphe (d'une couleur différente).</p>
# <p><u>Données :</u> M<sub>Soleil</sub> = 1048 M<sub>Jupiter</sub> et R<sub>Soleil</sub> = 9,96 R<sub>Jupiter</sub></p>
# <p><img src=danger.png width=24 style=display:inline-block; /> penser à réajuster les intervalles de valeurs affichées.</p>
# <p>Placer le Soleil sur votre graphe.</p>
# <p>Votre graphe doit afficher les légendes pour les exoplanètes, les étoiles, la Terre, Jupiter, le Soleil et la courbe de densité égale à celle de la Terre.</p>
# <p><img src=danger.png width=24 style=display:inline-block; /> il faut ajouter une virgule après la variable densite<code>densite, = axes.plot(...)</code></p>

# %%
#taper votre code ici ...

# %% [markdown]
# <p>Commentez votre graphe :</p>

# %% [markdown]
# <div class=reponse>Vos commentaires : .......................</div>

# %% [markdown]
# <div class=titre2  style=margin-top:400px;  >6. Annexes</div>
# <p>Le code ci-dessous est le code CSS pour le style de cette page</p>

# %%
# %%html
# <style>
#     #site , .p-DockPanel {background-color:#AAD;}
#     #notebook-container , .jp-Notebook {
#         background-color:#CCF;
#         }
#     p , p > * {
#         color:#24B;
#         font-size:16px;
#         font-family:"Comic Sans Ms",cursive;
#     }
#
#     .reponse {
#         color:#0A0;
#         background-color:#DFD;
#         border:solid 1px #0A0;
#         font-size:22px;
#         font-family:Times,serif;
#         padding:10px;
#     }
#     .titre1 {
#         color:#24B;
#         font-size:36px;
#         font-family:verdana;
#         margin:32px;
#         font-weight:bold;
#         text-align:center;
#     }
#     .titre2 {
#         color:#24B;
#         font-size:28px;
#         font-family:verdana;
#         margin:16px;
#         margin-top:80px;
#     }
#     .titre3 {
#         color:#24B;
#         font-size:24px;
#         font-family:verdana;
#         margin:16px;
#         margin-top:80px;
#     }
#
#     img {
#         display:inline-block;
#     }
#     .details *  {
#         color:#444;
#         font-size:12px;
#     }
#     .attention {
#         border: solid 1px #C00;
#         border-radius: 6px;
#         color: #C00;
#         background-color:#CAA;
#         padding:6px;
#     }
#     a {
#         font-family:arial;
#         color:#4C4;
#     }
#     code {
#         font-family:arial;
#     }
#     .surligne {
#         background-color:orange;
#     }
# </style>
# Out:
# <style>
#     #site , .p-DockPanel {background-color:#AAD;}
#     #notebook-container , .jp-Notebook {
#         background-color:#CCF;
#         }
#     p , p > * {
#         color:#24B;
#         font-size:16px;
#         font-family:"Comic Sans Ms",cursive;
#     }
#
#     .reponse {
#         color:#0A0;
#         background-color:#DFD;
#         border:solid 1px #0A0;
#         font-size:22px;
#         font-family:Times,serif;
#         padding:10px;
#     }
#     .titre1 {
#         color:#24B;
#         font-size:36px;
#         font-family:verdana;
#         margin:32px;
#         font-weight:bold;
#         text-align:center;
#     }
#     .titre2 {
#         color:#24B;
#         font-size:28px;
#         font-family:verdana;
#         margin:16px;
#         margin-top:80px;
#     }
#     .titre3 {
#         color:#24B;
#         font-size:24px;
#         font-family:verdana;
#         margin:16px;
#         margin-top:80px;
#     }
#
#     img {
# ...

# %% [markdown]
# Le code ci-dessous permet d'éviter de perdre la session au bout d'une trop longue inactivité

# %%
# %%javascript
#
# function repeter(){
# IPython.notebook.kernel.execute("a=1");
# }
# // execute a = 1 en python toutes les 8 minutes pendant 2h
# let timerId = setInterval(() => repeter(), 480000);

# %% [markdown]
# <a href="https://mybinder.org/v2/gh/lthumser/NSI/master?filepath=BDD_avec_python.ipynb" >lien vers cette page</a>
