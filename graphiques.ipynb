# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }
# // ce code facultatif sert à éviter d'avoir des cellules trop petites pour contenir les graphiques
# // ATTENTION ce code doit rester dans une seule cellule

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# ce code facultatif permet d'utiliser toute la largeur di navigateur

# %matplotlib notebook
# ce code facultatif permet d'obtenir des graphiques interactifs : zoomer, redimensionner (avec le coin en bas à droite), afficher les coordonnées du pointeur de la souris
# bug de Chrome : le bouton download ne fonctionne plus, et fonctionne mal avec Firefox

import matplotlib.pyplot as plt
# importation de la bibliothèque
# Out:
# <style>.container { width:100% !important; }</style>

# %%
x = [12,41,214]
y = [145,260,289]
plt.plot(x,y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
